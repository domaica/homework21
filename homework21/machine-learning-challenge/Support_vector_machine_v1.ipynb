# %% [markdown]
# # SVM - Support Vector Machine

# %%
# dependencies
import pandas as pd

# %%
# read csv data
df = pd.read_csv("resources/cumulative.csv")

df.head()
# Out:
#    rowid     kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0      1  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1      2  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2      3  10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 3      4  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4      5  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  ...  \
# 0      1.000              0              0              0  ...
# 1      0.969              0              0              0  ...
# 2      0.000              0              1              0  ...
# 3      0.000              0              1              0  ...
# 4      1.000              0              0              0  ...
#
#    koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# 0           -81.0      4.467           0.064          -0.096     0.927
# 1           -81.0      4.467           0.064          -0.096     0.927
# 2          -176.0      4.544           0.044          -0.176     0.868
# 3          -174.0      4.564           0.053          -0.168     0.791
# 4          -211.0      4.438           0.070          -0.210     1.046
#
#    koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag
# 0          0.105         -0.061  291.93423  48.141651      15.347
# 1          0.105         -0.061  291.93423  48.141651      15.347
# 2          0.233         -0.078  297.00482  48.134129      15.436
# 3          0.201         -0.067  285.53461  48.285210      15.597
# 4          0.334         -0.133  288.75488  48.226200      15.509
#
# [5 rows x 50 columns]

# %%
df = df.drop(columns=["rowid", "kepid", "kepoi_name", "kepler_name", "koi_pdisposition", "koi_score", "koi_tce_delivname"])
df
# Out:
#      koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0          CONFIRMED              0              0              0
# 1          CONFIRMED              0              0              0
# 2     FALSE POSITIVE              0              1              0
# 3     FALSE POSITIVE              0              1              0
# 4          CONFIRMED              0              0              0
# ...              ...            ...            ...            ...
# 9559  FALSE POSITIVE              0              0              0
# 9560  FALSE POSITIVE              0              1              1
# 9561       CANDIDATE              0              0              0
# 9562  FALSE POSITIVE              0              0              1
# 9563  FALSE POSITIVE              0              0              1
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# 0                 0    9.488036     2.780000e-05    -2.780000e-05
# 1                 0   54.418383     2.480000e-04    -2.480000e-04
# 2                 0   19.899140     1.490000e-05    -1.490000e-05
# 3                 0    1.736952     2.630000e-07    -2.630000e-07
# 4                 0    2.525592     3.760000e-06    -3.760000e-06
# ...             ...         ...              ...              ...
# 9559              1    8.589871     1.850000e-04    -1.850000e-04
# 9560              0    0.527699     1.160000e-07    -1.160000e-07
# 9561              0    1.739849     1.780000e-05    -1.780000e-05
# 9562              0    0.681402     2.430000e-06    -2.430000e-06
# 9563              1    4.856035     6.360000e-05    -6.360000e-05
#
#       koi_time0bk  koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  \
# 0      170.538750          0.002160  ...           -81.0      4.467
# 1      162.513840          0.003520  ...           -81.0      4.467
# 2      175.850252          0.000581  ...          -176.0      4.544
# 3      170.307565          0.000115  ...          -174.0      4.564
# 4      171.595550          0.001130  ...          -211.0      4.438
# ...           ...               ...  ...             ...        ...
# 9559   132.016100          0.015700  ...          -152.0      4.296
# 9560   131.705093          0.000170  ...          -166.0      4.529
# 9561   133.001270          0.007690  ...          -220.0      4.444
# 9562   132.181750          0.002850  ...          -236.0      4.447
# 9563   135.993300          0.010800  ...          -225.0      4.385
#
#       koi_slogg_err1  koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2  \
# 0              0.064          -0.096     0.927          0.105         -0.061
# 1              0.064          -0.096     0.927          0.105         -0.061
# 2              0.044          -0.176     0.868          0.233         -0.078
# 3              0.053          -0.168     0.791          0.201         -0.067
# 4              0.070          -0.210     1.046          0.334         -0.133
# ...              ...             ...       ...            ...            ...
# 9559           0.231          -0.189     1.088          0.313         -0.228
# 9560           0.035          -0.196     0.903          0.237         -0.079
# 9561           0.056          -0.224     1.031          0.341         -0.114
# 9562           0.056          -0.224     1.041          0.341         -0.114
# 9563           0.054          -0.216     1.193          0.410         -0.137
#
#              ra        dec  koi_kepmag
# 0     291.93423  48.141651      15.347
# 1     291.93423  48.141651      15.347
# 2     297.00482  48.134129      15.436
# 3     285.53461  48.285210      15.597
# 4     288.75488  48.226200      15.509
# ...         ...        ...         ...
# 9559  298.74921  46.973351      14.478
# 9560  297.18875  47.093819      14.082
# 9561  286.50937  47.163219      14.757
# 9562  294.16489  47.176281      15.385
# 9563  297.00977  47.121021      14.826
#
# [9564 rows x 43 columns]

# %%
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df
# Out:
#      koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0          CONFIRMED              0              0              0
# 1          CONFIRMED              0              0              0
# 2     FALSE POSITIVE              0              1              0
# 3     FALSE POSITIVE              0              1              0
# 4          CONFIRMED              0              0              0
# ...              ...            ...            ...            ...
# 9559  FALSE POSITIVE              0              0              0
# 9560  FALSE POSITIVE              0              1              1
# 9561       CANDIDATE              0              0              0
# 9562  FALSE POSITIVE              0              0              1
# 9563  FALSE POSITIVE              0              0              1
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# 0                 0    9.488036     2.780000e-05    -2.780000e-05
# 1                 0   54.418383     2.480000e-04    -2.480000e-04
# 2                 0   19.899140     1.490000e-05    -1.490000e-05
# 3                 0    1.736952     2.630000e-07    -2.630000e-07
# 4                 0    2.525592     3.760000e-06    -3.760000e-06
# ...             ...         ...              ...              ...
# 9559              1    8.589871     1.850000e-04    -1.850000e-04
# 9560              0    0.527699     1.160000e-07    -1.160000e-07
# 9561              0    1.739849     1.780000e-05    -1.780000e-05
# 9562              0    0.681402     2.430000e-06    -2.430000e-06
# 9563              1    4.856035     6.360000e-05    -6.360000e-05
#
#       koi_time0bk  koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  \
# 0      170.538750          0.002160  ...           -81.0      4.467
# 1      162.513840          0.003520  ...           -81.0      4.467
# 2      175.850252          0.000581  ...          -176.0      4.544
# 3      170.307565          0.000115  ...          -174.0      4.564
# 4      171.595550          0.001130  ...          -211.0      4.438
# ...           ...               ...  ...             ...        ...
# 9559   132.016100          0.015700  ...          -152.0      4.296
# 9560   131.705093          0.000170  ...          -166.0      4.529
# 9561   133.001270          0.007690  ...          -220.0      4.444
# 9562   132.181750          0.002850  ...          -236.0      4.447
# 9563   135.993300          0.010800  ...          -225.0      4.385
#
#       koi_slogg_err1  koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2  \
# 0              0.064          -0.096     0.927          0.105         -0.061
# 1              0.064          -0.096     0.927          0.105         -0.061
# 2              0.044          -0.176     0.868          0.233         -0.078
# 3              0.053          -0.168     0.791          0.201         -0.067
# 4              0.070          -0.210     1.046          0.334         -0.133
# ...              ...             ...       ...            ...            ...
# 9559           0.231          -0.189     1.088          0.313         -0.228
# 9560           0.035          -0.196     0.903          0.237         -0.079
# 9561           0.056          -0.224     1.031          0.341         -0.114
# 9562           0.056          -0.224     1.041          0.341         -0.114
# 9563           0.054          -0.216     1.193          0.410         -0.137
#
#              ra        dec  koi_kepmag
# 0     291.93423  48.141651      15.347
# 1     291.93423  48.141651      15.347
# 2     297.00482  48.134129      15.436
# 3     285.53461  48.285210      15.597
# 4     288.75488  48.226200      15.509
# ...         ...        ...         ...
# 9559  298.74921  46.973351      14.478
# 9560  297.18875  47.093819      14.082
# 9561  286.50937  47.163219      14.757
# 9562  294.16489  47.176281      15.385
# 9563  297.00977  47.121021      14.826
#
# [8744 rows x 41 columns]

# %% [markdown]
# ## Test split

# %%
# Assign the X and y variables
X = df.drop("koi_disposition", axis=1)
y = df["koi_disposition"]

# %%
# Split data into training and testing data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 3206              0              1              1              0   31.805143
# 3954              0              0              0              0   24.560711
# 1410              0              0              0              0    7.560522
# 5865              0              0              0              0    4.644901
# 340               0              0              1              1    2.037441
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 3206         0.000042        -0.000042    186.38905           0.00105
# 3954         0.000375        -0.000375    146.79380           0.01610
# 1410         0.000026        -0.000026    134.47889           0.00270
# 5865         0.000038        -0.000038    133.67436           0.00786
# 340          0.000010        -0.000010    133.59962           0.00390
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 3206          -0.00105  ...          -161.0      4.545           0.044
# 3954          -0.01610  ...          -135.0      4.192           0.137
# 1410          -0.00270  ...          -211.0      4.503           0.052
# 5865          -0.00786  ...           -85.0      4.540           0.052
# 340           -0.00390  ...          -207.0      4.415           0.087
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 3206          -0.176     0.863          0.217         -0.072  298.04453
# 3954          -0.125     1.499          0.272         -0.245  289.92145
# 1410          -0.208     0.940          0.282         -0.094  283.84515
# 5865          -0.017     0.770          0.027         -0.046  282.34305
# 340           -0.203     1.015          0.312         -0.134  295.79526
#
#             dec  koi_kepmag
# 3206  40.086361      14.517
# 3954  46.744560      12.805
# 1410  44.609089      15.986
# 5865  48.340778      14.480
# 340   47.663960      14.187
#
# [5 rows x 40 columns]

# %% [markdown]
# ## Preprocess data (MinMaxScaler)

# %%
from sklearn.preprocessing import MinMaxScaler

X_scaler = MinMaxScaler().fit(X_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Train SVM

# %%
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train_scaled, y_train)
# Out:
# SVC(kernel='linear')

# %%
print(f"Training Data Score: {model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.8508691674290942
# Testing Data Score: 0.8472095150960659

# %% [markdown]
# ## Hyperparameter Tuning

# %%
# Create the GridSearchCV model

from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10],
              'gamma': [0.0001, 0.001, 0.01]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Train the model with GridSearch
# Fit the model using the grid search estimator. 
# This will take the SVC model and try each combination of parameters
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END .................C=1, gamma=0.0001;, score=0.851 total time=   0.3s
# [CV 2/5] END .................C=1, gamma=0.0001;, score=0.832 total time=   0.3s
# [CV 3/5] END .................C=1, gamma=0.0001;, score=0.837 total time=   0.3s
# [CV 4/5] END .................C=1, gamma=0.0001;, score=0.834 total time=   0.3s
# [CV 5/5] END .................C=1, gamma=0.0001;, score=0.865 total time=   0.3s
# [CV 1/5] END ..................C=1, gamma=0.001;, score=0.851 total time=   0.3s
# [CV 2/5] END ..................C=1, gamma=0.001;, score=0.832 total time=   0.3s
# [CV 3/5] END ..................C=1, gamma=0.001;, score=0.837 total time=   0.3s
# [CV 4/5] END ..................C=1, gamma=0.001;, score=0.834 total time=   0.3s
# [CV 5/5] END ..................C=1, gamma=0.001;, score=0.865 total time=   0.3s
# [CV 1/5] END ...................C=1, gamma=0.01;, score=0.851 total time=   0.3s
# [CV 2/5] END ...................C=1, gamma=0.01;, score=0.832 total time=   0.3s
# [CV 3/5] END ...................C=1, gamma=0.01;, score=0.837 total time=   0.3s
# [CV 4/5] END ...................C=1, gamma=0.01;, score=0.834 total time=   0.3s
# [CV 5/5] END ...................C=1, gamma=0.01;, score=0.865 total time=   0.3s
# [CV 1/5] END .................C=5, gamma=0.0001;, score=0.877 total time=   0.3s
# [CV 2/5] END .................C=5, gamma=0.0001;, score=0.847 total time=   0.4s
# [CV 3/5] END .................C=5, gamma=0.0001;, score=0.867 total time=   0.3s
# [CV 4/5] END .................C=5, gamma=0.0001;, score=0.852 total time=   0.3s
# [CV 5/5] END .................C=5, gamma=0.0001;, score=0.880 total time=   0.4s
# [CV 1/5] END ..................C=5, gamma=0.001;, score=0.877 total time=   0.4s
# [CV 2/5] END ..................C=5, gamma=0.001;, score=0.847 total time=   0.4s
# [CV 3/5] END ..................C=5, gamma=0.001;, score=0.867 total time=   0.3s
# [CV 4/5] END ..................C=5, gamma=0.001;, score=0.852 total time=   0.3s
# [CV 5/5] END ..................C=5, gamma=0.001;, score=0.880 total time=   0.4s
# [CV 1/5] END ...................C=5, gamma=0.01;, score=0.877 total time=   0.3s
# [CV 2/5] END ...................C=5, gamma=0.01;, score=0.847 total time=   0.4s
# [CV 3/5] END ...................C=5, gamma=0.01;, score=0.867 total time=   0.3s
# [CV 4/5] END ...................C=5, gamma=0.01;, score=0.852 total time=   0.3s
# [CV 5/5] END ...................C=5, gamma=0.01;, score=0.880 total time=   0.4s
# [CV 1/5] END ................C=10, gamma=0.0001;, score=0.878 total time=   0.4s
# [CV 2/5] END ................C=10, gamma=0.0001;, score=0.851 total time=   0.5s
# [CV 3/5] END ................C=10, gamma=0.0001;, score=0.879 total time=   0.4s
# [CV 4/5] END ................C=10, gamma=0.0001;, score=0.859 total time=   0.3s
# [CV 5/5] END ................C=10, gamma=0.0001;, score=0.890 total time=   0.4s
# [CV 1/5] END .................C=10, gamma=0.001;, score=0.878 total time=   0.4s
# [CV 2/5] END .................C=10, gamma=0.001;, score=0.851 total time=   0.5s
# [CV 3/5] END .................C=10, gamma=0.001;, score=0.879 total time=   0.3s
# [CV 4/5] END .................C=10, gamma=0.001;, score=0.859 total time=   0.3s
# [CV 5/5] END .................C=10, gamma=0.001;, score=0.890 total time=   0.4s
# [CV 1/5] END ..................C=10, gamma=0.01;, score=0.878 total time=   0.4s
# [CV 2/5] END ..................C=10, gamma=0.01;, score=0.851 total time=   0.5s
# [CV 3/5] END ..................C=10, gamma=0.01;, score=0.879 total time=   0.4s
# [CV 4/5] END ..................C=10, gamma=0.01;, score=0.859 total time=   0.3s
# [CV 5/5] END ..................C=10, gamma=0.01;, score=0.890 total time=   0.4s
# GridSearchCV(estimator=SVC(kernel='linear'),
#              param_grid={'C': [1, 5, 10], 'gamma': [0.0001, 0.001, 0.01]},
#              verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 10, 'gamma': 0.0001}
# 0.8713032083124036

# %%
# Make predictions with the hypertuned model
predictions = grid.predict(X_test_scaled)

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions,
                            target_names=["CONFIRMED", "FALSE POSITIVE", "CANDIDATE"]))
# Out:
#                 precision    recall  f1-score   support
#
#      CONFIRMED       0.85      0.61      0.71       529
# FALSE POSITIVE       0.72      0.88      0.79       568
#      CANDIDATE       0.98      1.00      0.99      1089
#
#       accuracy                           0.87      2186
#      macro avg       0.85      0.83      0.83      2186
#   weighted avg       0.88      0.87      0.87      2186
