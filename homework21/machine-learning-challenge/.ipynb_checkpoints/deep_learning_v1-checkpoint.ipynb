# %% [markdown]
# # Deep learning model

# %%
# !pip install tensorflow --user --upgrade

# %%
# !pip install keras --user --upgrade

# %%
# dependencies
import pandas as pd

# %%
# read csv data
df = pd.read_csv("resources/cumulative.csv")

df.head()
# Out:
#    rowid     kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0      1  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1      2  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2      3  10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 3      4  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4      5  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  ...  \
# 0      1.000              0              0              0  ...
# 1      0.969              0              0              0  ...
# 2      0.000              0              1              0  ...
# 3      0.000              0              1              0  ...
# 4      1.000              0              0              0  ...
#
#    koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# 0           -81.0      4.467           0.064          -0.096     0.927
# 1           -81.0      4.467           0.064          -0.096     0.927
# 2          -176.0      4.544           0.044          -0.176     0.868
# 3          -174.0      4.564           0.053          -0.168     0.791
# 4          -211.0      4.438           0.070          -0.210     1.046
#
#    koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag
# 0          0.105         -0.061  291.93423  48.141651      15.347
# 1          0.105         -0.061  291.93423  48.141651      15.347
# 2          0.233         -0.078  297.00482  48.134129      15.436
# 3          0.201         -0.067  285.53461  48.285210      15.597
# 4          0.334         -0.133  288.75488  48.226200      15.509
#
# [5 rows x 50 columns]

# %%
df = df.drop(columns=["rowid", "kepid", "kepoi_name", "kepler_name", "koi_pdisposition", "koi_score", "koi_tce_delivname"])
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1       CONFIRMED              0              0              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3  FALSE POSITIVE              0              1              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0    9.488036     2.780000e-05    -2.780000e-05   170.538750
# 1   54.418383     2.480000e-04    -2.480000e-04   162.513840
# 2   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 3    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 4    2.525592     3.760000e-06    -3.760000e-06   171.595550
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.002160  ...           -81.0      4.467           0.064
# 1          0.003520  ...           -81.0      4.467           0.064
# 2          0.000581  ...          -176.0      4.544           0.044
# 3          0.000115  ...          -174.0      4.564           0.053
# 4          0.001130  ...          -211.0      4.438           0.070
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.096     0.927          0.105         -0.061  291.93423
# 2          -0.176     0.868          0.233         -0.078  297.00482
# 3          -0.168     0.791          0.201         -0.067  285.53461
# 4          -0.210     1.046          0.334         -0.133  288.75488
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.141651      15.347
# 2  48.134129      15.436
# 3  48.285210      15.597
# 4  48.226200      15.509
#
# [5 rows x 43 columns]

# %%
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1       CONFIRMED              0              0              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3  FALSE POSITIVE              0              1              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0    9.488036     2.780000e-05    -2.780000e-05   170.538750
# 1   54.418383     2.480000e-04    -2.480000e-04   162.513840
# 2   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 3    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 4    2.525592     3.760000e-06    -3.760000e-06   171.595550
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.002160  ...           -81.0      4.467           0.064
# 1          0.003520  ...           -81.0      4.467           0.064
# 2          0.000581  ...          -176.0      4.544           0.044
# 3          0.000115  ...          -174.0      4.564           0.053
# 4          0.001130  ...          -211.0      4.438           0.070
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.096     0.927          0.105         -0.061  291.93423
# 2          -0.176     0.868          0.233         -0.078  297.00482
# 3          -0.168     0.791          0.201         -0.067  285.53461
# 4          -0.210     1.046          0.334         -0.133  288.75488
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.141651      15.347
# 2  48.134129      15.436
# 3  48.285210      15.597
# 4  48.226200      15.509
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Test split

# %%
# Asssign the X and y values
X = df.drop("koi_disposition", axis=1)
y = df["koi_disposition"]
print(X.shape, y.shape)
# Out:
# (8744, 40) (8744,)

# %%
#Split data into training and testing data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)
# X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 3206              0              1              1              0   31.805143
# 3954              0              0              0              0   24.560711
# 1410              0              0              0              0    7.560522
# 5865              0              0              0              0    4.644901
# 340               0              0              1              1    2.037441
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 3206         0.000042        -0.000042    186.38905           0.00105
# 3954         0.000375        -0.000375    146.79380           0.01610
# 1410         0.000026        -0.000026    134.47889           0.00270
# 5865         0.000038        -0.000038    133.67436           0.00786
# 340          0.000010        -0.000010    133.59962           0.00390
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 3206          -0.00105  ...          -161.0      4.545           0.044
# 3954          -0.01610  ...          -135.0      4.192           0.137
# 1410          -0.00270  ...          -211.0      4.503           0.052
# 5865          -0.00786  ...           -85.0      4.540           0.052
# 340           -0.00390  ...          -207.0      4.415           0.087
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 3206          -0.176     0.863          0.217         -0.072  298.04453
# 3954          -0.125     1.499          0.272         -0.245  289.92145
# 1410          -0.208     0.940          0.282         -0.094  283.84515
# 5865          -0.017     0.770          0.027         -0.046  282.34305
# 340           -0.203     1.015          0.312         -0.134  295.79526
#
#             dec  koi_kepmag
# 3206  40.086361      14.517
# 3954  46.744560      12.805
# 1410  44.609089      15.986
# 5865  48.340778      14.480
# 340   47.663960      14.187
#
# [5 rows x 40 columns]

# %% [markdown]
# ## Scale the data with MinMaxScaler

# %%
# Fit data to the MinMaxScaler
from sklearn.preprocessing import MinMaxScaler

X_scaler = MinMaxScaler().fit(X_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from keras.utils import to_categorical

# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %% [markdown]
# ## Create Deep Learning Model

# %%
from keras.models import Sequential
from keras.layers import Dense

# Create the model
model = Sequential()
# Add two layers of nodes
model.add(Dense(units=120, activation='relu', input_dim=40))
model.add(Dense(units=120, activation='relu'))
# Add the output layer
model.add(Dense(units=3, activation='softmax'))

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 120)               4920
# _________________________________________________________________
# dense_1 (Dense)              (None, 120)               14520
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 363
# =================================================================
# Total params: 19,803
# Trainable params: 19,803
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the model
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 205/205 - 0s - loss: 0.4895 - accuracy: 0.7543
# Epoch 2/100
# 205/205 - 0s - loss: 0.3641 - accuracy: 0.8117
# Epoch 3/100
# 205/205 - 0s - loss: 0.3540 - accuracy: 0.8225
# Epoch 4/100
# 205/205 - 0s - loss: 0.3438 - accuracy: 0.8314
# Epoch 5/100
# 205/205 - 0s - loss: 0.3319 - accuracy: 0.8423
# Epoch 6/100
# 205/205 - 0s - loss: 0.3212 - accuracy: 0.8489
# Epoch 7/100
# 205/205 - 0s - loss: 0.3220 - accuracy: 0.8515
# Epoch 8/100
# 205/205 - 0s - loss: 0.3173 - accuracy: 0.8524
# Epoch 9/100
# 205/205 - 0s - loss: 0.3122 - accuracy: 0.8564
# Epoch 10/100
# 205/205 - 0s - loss: 0.3032 - accuracy: 0.8640
# Epoch 11/100
# 205/205 - 0s - loss: 0.2992 - accuracy: 0.8704
# Epoch 12/100
# 205/205 - 0s - loss: 0.2949 - accuracy: 0.8667
# Epoch 13/100
# 205/205 - 0s - loss: 0.2968 - accuracy: 0.8708
# Epoch 14/100
# 205/205 - 0s - loss: 0.2921 - accuracy: 0.8716
# Epoch 15/100
# 205/205 - 0s - loss: 0.2867 - accuracy: 0.8689
# Epoch 16/100
# 205/205 - 0s - loss: 0.2817 - accuracy: 0.8747
# Epoch 17/100
# 205/205 - 0s - loss: 0.2820 - accuracy: 0.8722
# Epoch 18/100
# 205/205 - 0s - loss: 0.2756 - accuracy: 0.8823
# Epoch 19/100
# 205/205 - 0s - loss: 0.2803 - accuracy: 0.8725
# Epoch 20/100
# 205/205 - 0s - loss: 0.2750 - accuracy: 0.8789
# Epoch 21/100
# 205/205 - 0s - loss: 0.2720 - accuracy: 0.8841
# Epoch 22/100
# 205/205 - 0s - loss: 0.2746 - accuracy: 0.8783
# Epoch 23/100
# 205/205 - 0s - loss: 0.2671 - accuracy: 0.8838
# Epoch 24/100
# 205/205 - 0s - loss: 0.2640 - accuracy: 0.8850
# Epoch 25/100
# 205/205 - 0s - loss: 0.2653 - accuracy: 0.8838
# Epoch 26/100
# 205/205 - 0s - loss: 0.2655 - accuracy: 0.8824
# Epoch 27/100
# 205/205 - 0s - loss: 0.2740 - accuracy: 0.8742
# Epoch 28/100
# 205/205 - 0s - loss: 0.2644 - accuracy: 0.8835
# Epoch 29/100
# 205/205 - 0s - loss: 0.2609 - accuracy: 0.8846
# Epoch 30/100
# 205/205 - 0s - loss: 0.2668 - accuracy: 0.8823
# Epoch 31/100
# 205/205 - 0s - loss: 0.2589 - accuracy: 0.8872
# Epoch 32/100
# 205/205 - 0s - loss: 0.2607 - accuracy: 0.8856
# Epoch 33/100
# 205/205 - 0s - loss: 0.2556 - accuracy: 0.8869
# Epoch 34/100
# 205/205 - 0s - loss: 0.2537 - accuracy: 0.8869
# Epoch 35/100
# 205/205 - 0s - loss: 0.2578 - accuracy: 0.8855
# Epoch 36/100
# 205/205 - 0s - loss: 0.2532 - accuracy: 0.8876
# Epoch 37/100
# 205/205 - 0s - loss: 0.2491 - accuracy: 0.8914
# Epoch 38/100
# 205/205 - 0s - loss: 0.2550 - accuracy: 0.8855
# Epoch 39/100
# 205/205 - 0s - loss: 0.2510 - accuracy: 0.8905
# Epoch 40/100
# 205/205 - 0s - loss: 0.2473 - accuracy: 0.8940
# Epoch 41/100
# 205/205 - 0s - loss: 0.2488 - accuracy: 0.8933
# Epoch 42/100
# 205/205 - 0s - loss: 0.2495 - accuracy: 0.8916
# Epoch 43/100
# 205/205 - 0s - loss: 0.2443 - accuracy: 0.8974
# Epoch 44/100
# 205/205 - 0s - loss: 0.2469 - accuracy: 0.8931
# Epoch 45/100
# 205/205 - 0s - loss: 0.2489 - accuracy: 0.8928
# Epoch 46/100
# 205/205 - 0s - loss: 0.2443 - accuracy: 0.8968
# Epoch 47/100
# 205/205 - 0s - loss: 0.2443 - accuracy: 0.8943
# Epoch 48/100
# 205/205 - 0s - loss: 0.2423 - accuracy: 0.8933
# Epoch 49/100
# 205/205 - 0s - loss: 0.2456 - accuracy: 0.8927
# Epoch 50/100
# 205/205 - 0s - loss: 0.2392 - accuracy: 0.8980
# Epoch 51/100
# 205/205 - 0s - loss: 0.2501 - accuracy: 0.8879
# Epoch 52/100
# 205/205 - 0s - loss: 0.2384 - accuracy: 0.8957
# Epoch 53/100
# 205/205 - 0s - loss: 0.2452 - accuracy: 0.8888
# Epoch 54/100
# 205/205 - 0s - loss: 0.2392 - accuracy: 0.8978
# Epoch 55/100
# 205/205 - 0s - loss: 0.2431 - accuracy: 0.8927
# Epoch 56/100
# 205/205 - 0s - loss: 0.2403 - accuracy: 0.8940
# Epoch 57/100
# 205/205 - 0s - loss: 0.2478 - accuracy: 0.8904
# Epoch 58/100
# 205/205 - 0s - loss: 0.2345 - accuracy: 0.8975
# Epoch 59/100
# 205/205 - 0s - loss: 0.2372 - accuracy: 0.8986
# Epoch 60/100
# 205/205 - 0s - loss: 0.2366 - accuracy: 0.8925
# Epoch 61/100
# 205/205 - 0s - loss: 0.2372 - accuracy: 0.8948
# Epoch 62/100
# 205/205 - 0s - loss: 0.2364 - accuracy: 0.8957
# Epoch 63/100
# 205/205 - 0s - loss: 0.2314 - accuracy: 0.9024
# Epoch 64/100
# 205/205 - 0s - loss: 0.2366 - accuracy: 0.8945
# Epoch 65/100
# 205/205 - 0s - loss: 0.2316 - accuracy: 0.9000
# Epoch 66/100
# 205/205 - 0s - loss: 0.2324 - accuracy: 0.8968
# Epoch 67/100
# 205/205 - 0s - loss: 0.2372 - accuracy: 0.8955
# Epoch 68/100
# 205/205 - 0s - loss: 0.2326 - accuracy: 0.8963
# Epoch 69/100
# 205/205 - 0s - loss: 0.2289 - accuracy: 0.8994
# Epoch 70/100
# 205/205 - 0s - loss: 0.2308 - accuracy: 0.9001
# Epoch 71/100
# 205/205 - 0s - loss: 0.2303 - accuracy: 0.8992
# Epoch 72/100
# 205/205 - 0s - loss: 0.2286 - accuracy: 0.8989
# Epoch 73/100
# 205/205 - 0s - loss: 0.2324 - accuracy: 0.8969
# Epoch 74/100
# 205/205 - 0s - loss: 0.2277 - accuracy: 0.9016
# Epoch 75/100
# 205/205 - 0s - loss: 0.2269 - accuracy: 0.9012
# Epoch 76/100
# 205/205 - 0s - loss: 0.2286 - accuracy: 0.9012
# Epoch 77/100
# 205/205 - 0s - loss: 0.2271 - accuracy: 0.8994
# Epoch 78/100
# 205/205 - 0s - loss: 0.2266 - accuracy: 0.9015
# Epoch 79/100
# 205/205 - 0s - loss: 0.2285 - accuracy: 0.9010
# Epoch 80/100
# 205/205 - 0s - loss: 0.2238 - accuracy: 0.9016
# Epoch 81/100
# 205/205 - 0s - loss: 0.2250 - accuracy: 0.9026
# Epoch 82/100
# 205/205 - 0s - loss: 0.2249 - accuracy: 0.8986
# Epoch 83/100
# 205/205 - 0s - loss: 0.2308 - accuracy: 0.8945
# Epoch 84/100
# 205/205 - 0s - loss: 0.2309 - accuracy: 0.8957
# Epoch 85/100
# 205/205 - 0s - loss: 0.2211 - accuracy: 0.9044
# Epoch 86/100
# 205/205 - 0s - loss: 0.2250 - accuracy: 0.9013
# Epoch 87/100
# 205/205 - 0s - loss: 0.2238 - accuracy: 0.9047
# Epoch 88/100
# 205/205 - 0s - loss: 0.2232 - accuracy: 0.9003
# Epoch 89/100
# 205/205 - 0s - loss: 0.2205 - accuracy: 0.9029
# Epoch 90/100
# 205/205 - 0s - loss: 0.2235 - accuracy: 0.9032
# Epoch 91/100
# 205/205 - 0s - loss: 0.2195 - accuracy: 0.9035
# Epoch 92/100
# 205/205 - 0s - loss: 0.2190 - accuracy: 0.9032
# Epoch 93/100
# 205/205 - 0s - loss: 0.2203 - accuracy: 0.9041
# Epoch 94/100
# 205/205 - 0s - loss: 0.2247 - accuracy: 0.8998
# Epoch 95/100
# 205/205 - 0s - loss: 0.2192 - accuracy: 0.9044
# Epoch 96/100
# 205/205 - 0s - loss: 0.2218 - accuracy: 0.9006
# Epoch 97/100
# 205/205 - 0s - loss: 0.2163 - accuracy: 0.9048
# Epoch 98/100
# 205/205 - 0s - loss: 0.2170 - accuracy: 0.9035
# Epoch 99/100
# 205/205 - 0s - loss: 0.2177 - accuracy: 0.9024
# Epoch 100/100
# 205/205 - 0s - loss: 0.2201 - accuracy: 0.9050

# %% [markdown]
# ## Quantify model

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 69/69 - 0s - loss: 0.2727 - accuracy: 0.8824
# Normal Neural Network - Loss: 0.2726641595363617, Accuracy: 0.8824336528778076

# %% [markdown]
# ## Predictions

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:5])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)

# %%
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:5])}")
# Out:
# Predicted classes: ['FALSE POSITIVE' 'CONFIRMED' 'FALSE POSITIVE' 'FALSE POSITIVE'
#  'CONFIRMED']
# Actual Labels: ['FALSE POSITIVE', 'CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED']
