# %% [markdown]
# # KNN -  Nearest Neighbor

# %%
# dependencies
import pandas as pd

# %%
# read csv data
df = pd.read_csv("resources/cumulative.csv")

df.head()
# Out:
#    rowid     kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0      1  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1      2  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2      3  10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 3      4  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4      5  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  ...  \
# 0      1.000              0              0              0  ...
# 1      0.969              0              0              0  ...
# 2      0.000              0              1              0  ...
# 3      0.000              0              1              0  ...
# 4      1.000              0              0              0  ...
#
#    koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# 0           -81.0      4.467           0.064          -0.096     0.927
# 1           -81.0      4.467           0.064          -0.096     0.927
# 2          -176.0      4.544           0.044          -0.176     0.868
# 3          -174.0      4.564           0.053          -0.168     0.791
# 4          -211.0      4.438           0.070          -0.210     1.046
#
#    koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag
# 0          0.105         -0.061  291.93423  48.141651      15.347
# 1          0.105         -0.061  291.93423  48.141651      15.347
# 2          0.233         -0.078  297.00482  48.134129      15.436
# 3          0.201         -0.067  285.53461  48.285210      15.597
# 4          0.334         -0.133  288.75488  48.226200      15.509
#
# [5 rows x 50 columns]

# %%
df = df.drop(columns=["rowid", "kepid", "kepoi_name", "kepler_name", "koi_pdisposition", "koi_score", "koi_tce_delivname"])
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1       CONFIRMED              0              0              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3  FALSE POSITIVE              0              1              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0    9.488036     2.780000e-05    -2.780000e-05   170.538750
# 1   54.418383     2.480000e-04    -2.480000e-04   162.513840
# 2   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 3    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 4    2.525592     3.760000e-06    -3.760000e-06   171.595550
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.002160  ...           -81.0      4.467           0.064
# 1          0.003520  ...           -81.0      4.467           0.064
# 2          0.000581  ...          -176.0      4.544           0.044
# 3          0.000115  ...          -174.0      4.564           0.053
# 4          0.001130  ...          -211.0      4.438           0.070
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.096     0.927          0.105         -0.061  291.93423
# 2          -0.176     0.868          0.233         -0.078  297.00482
# 3          -0.168     0.791          0.201         -0.067  285.53461
# 4          -0.210     1.046          0.334         -0.133  288.75488
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.141651      15.347
# 2  48.134129      15.436
# 3  48.285210      15.597
# 4  48.226200      15.509
#
# [5 rows x 43 columns]

# %%
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1       CONFIRMED              0              0              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3  FALSE POSITIVE              0              1              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0    9.488036     2.780000e-05    -2.780000e-05   170.538750
# 1   54.418383     2.480000e-04    -2.480000e-04   162.513840
# 2   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 3    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 4    2.525592     3.760000e-06    -3.760000e-06   171.595550
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.002160  ...           -81.0      4.467           0.064
# 1          0.003520  ...           -81.0      4.467           0.064
# 2          0.000581  ...          -176.0      4.544           0.044
# 3          0.000115  ...          -174.0      4.564           0.053
# 4          0.001130  ...          -211.0      4.438           0.070
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.096     0.927          0.105         -0.061  291.93423
# 2          -0.176     0.868          0.233         -0.078  297.00482
# 3          -0.168     0.791          0.201         -0.067  285.53461
# 4          -0.210     1.046          0.334         -0.133  288.75488
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.141651      15.347
# 2  48.134129      15.436
# 3  48.285210      15.597
# 4  48.226200      15.509
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Test split

# %%
# Dependencies to KNN

import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

# %%
# Assign the X and y values
X = df.drop("koi_disposition", axis=1)
y = df["koi_disposition"]

# %%
#Split data into training and testing data
# from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 8017              0              1              1              0    0.806277
# 1233              0              1              1              0    3.582077
# 2592              0              0              0              0    5.060923
# 4770              0              1              0              1    8.480304
# 6632              0              0              0              1    4.994716
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 8017     4.950000e-06    -4.950000e-06   131.785670          0.006720
# 1233     4.320000e-06    -4.320000e-06   355.515064          0.000864
# 2592     2.620000e-05    -2.620000e-05   134.473160          0.004730
# 4770     3.320000e-07    -3.320000e-07   135.854534          0.000031
# 6632     4.500000e-05    -4.500000e-05   136.183300          0.009500
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 8017         -0.006720  ...          -184.0      4.471           0.054
# 1233         -0.000864  ...          -235.0      4.422           0.090
# 2592         -0.004730  ...          -112.0      4.492           0.048
# 4770         -0.000031  ...          -169.0      3.946           0.195
# 6632         -0.009500  ...          -194.0      3.706           0.320
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 8017          -0.229     0.996          0.324         -0.108  290.81723
# 1233          -0.195     0.993          0.283         -0.131  296.07822
# 2592          -0.112     0.911          0.121         -0.060  289.91742
# 4770          -0.105     2.210          0.375         -0.563  298.80020
# 6632          -0.080     2.830          0.458         -1.068  282.58215
#
#             dec  koi_kepmag
# 8017  38.539120      13.614
# 1233  43.136940      15.193
# 2592  40.828606      13.346
# 4770  46.665539       7.631
# 6632  46.815510      13.352
#
# [5 rows x 40 columns]

# %%
# Scaling the independent variables for analysis
# X_scaler = StandardScaler().fit(X.reshape(-1, 1))
X_scaler = StandardScaler().fit(X)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Loop through different k values to see which has the highest accuracy
# Note: We only use odd numbers because we don't want any ties
train_scores = []
test_scores = []
for k in range(1, 20, 2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)
    train_score = knn.score(X_train_scaled, y_train)
    test_score = knn.score(X_test_scaled, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    print(f"k: {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")
    
    
plt.plot(range(1, 20, 2), train_scores, marker='o')
plt.plot(range(1, 20, 2), test_scores, marker="x")
plt.xlabel("k neighbors")
plt.ylabel("Testing accuracy Score")
plt.show()
# Out:
# k: 1, Train/Test Score: 1.000/0.794
# k: 3, Train/Test Score: 0.913/0.819
# k: 5, Train/Test Score: 0.893/0.833
# k: 7, Train/Test Score: 0.880/0.830
# k: 9, Train/Test Score: 0.872/0.827
# k: 11, Train/Test Score: 0.869/0.829
# k: 13, Train/Test Score: 0.866/0.827
# k: 15, Train/Test Score: 0.862/0.828
# k: 17, Train/Test Score: 0.860/0.830
# k: 19, Train/Test Score: 0.857/0.830

# %%
# Note that k: 19 provides the best accuracy (lowest difference)
knn = KNeighborsClassifier(n_neighbors=19)
knn.fit(X_train, y_train)
print('k=19 Test Acc: %.3f' % knn.score(X_test, y_test))
# Out:
# k=19 Test Acc: 0.660

# %%
# Calculate classification report
from sklearn.metrics import classification_report
# print(classification_report(y_test, predictions,
#                             target_names=["CONFIRMED", "FALSE POSITIVE", "CANDIDATE"]))

# Print the classifiation report checking the accuracy rate of the model
print(classification_report(y_test, knn.predict(X_test)))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.47      0.38      0.42       523
#      CONFIRMED       0.62      0.69      0.65       594
# FALSE POSITIVE       0.76      0.78      0.77      1069
#
#       accuracy                           0.66      2186
#      macro avg       0.62      0.62      0.61      2186
#   weighted avg       0.65      0.66      0.65      2186
